# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# ADESALA DANIEL
# student

# %% [markdown]
# I am interested in Data science because i love working with and getting insights from data. I also love Artificial Intelligence.

# %% [markdown]
# <h3> The code below is supposed to perform a basic arithmetic function of addition of integers in variables</h3>

# %%
x = 2
y = 7
print(x+y)
# Out:
# 9

# %% [markdown]
# <h4> Search <a href='google.com'> google </a> for these;</h4>
# <ul>
#     <li> IBM </li> <hr>
#     <li> Data science</li>
# </ul>
